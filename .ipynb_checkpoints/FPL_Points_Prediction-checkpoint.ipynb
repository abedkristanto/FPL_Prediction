# %% [markdown]
# # Fantasy Premier League Points Prediction Using Weighted Moving Average
#
# ### 1. Extract Data
# #### 1.1. Selected Players Data Frame

# %%
import pandas as pd

pd.set_option('display.max_rows', 100)
players_df = pd.read_csv('players.csv').set_index('idplayers')
players_df.head()
# Out:
#                          name club position
# idplayers
# DEF1          Rayan Ait Nouri  WOL      DEF
# DEF10        Timothy Castagne  LEI      DEF
# DEF11      Jannik Vestergaard  SOU      DEF
# DEF12             Reece James  CHE      DEF
# DEF13       Gabriel Magalhães  ARS      DEF

# %% [markdown]
# #### 1.2. Gameweeks Players' Performance Data Frame

# %%
gw_perform_df = pd.read_csv('performance.csv')
gw_perform_df.head()
# Out:
#   entry_id player_id club  points  bps  ict_index  gameweek  fdr
# 0  GW01011      DEF1  WOL       0    0        0.0         1    4
# 1  GW02011      DEF1  WOL       0    0        0.0         2    4
# 2  GW03011      DEF1  WOL       0    0        0.0         3    2
# 3  GW04011      DEF1  WOL       0    0        0.0         4    2
# 4  GW05011      DEF1  WOL       0    0        0.0         5    2

# %% [markdown]
# #### 1.3. Club's Fixture Difficulty Rating (FDR) Data Frame

# %%
fdr_df = pd.read_csv('fdr.csv').set_index(['club_id','gameweek'])
fdr_df.head()
# Out:
#                  f_entryid club_name  fdr
# club_id gameweek
# ARS     1          ARSGW01   Arsenal    2
#         2          ARSGW02   Arsenal    2
#         3          ARSGW03   Arsenal    5
#         4          ARSGW04   Arsenal    3
#         5          ARSGW05   Arsenal    5

# %% [markdown]
# ### 2. Relationship Between Gameweek Points and Bonus Points System (BPS)

# %%
import seaborn as sns
from sklearn import linear_model
from sklearn.metrics import r2_score

regr = linear_model.LinearRegression()
x = gw_perform_df[['bps']]
y = gw_perform_df[['points']]
regr.fit (x, y)

#Plotting
bps_plot = sns.lmplot(data=gw_perform_df, x='bps', y='points')
bps_plot.set_axis_labels('Bonus Point System', 'Points')

# The coefficients
print ('Regression Equation: ', regr.coef_[0][0], '* x', '+ (', regr.intercept_[0], ')')
y_hat = regr.predict(x)
print("R2-score: %.2f" % r2_score(y_hat, y))
# Out:
# Regression Equation:  0.2661265091798837 * x + ( -0.09788087422218883 )
# R2-score: 0.84

# %% [markdown]
# ### 3. Points Prediction Based On 3 Previous Gameweeks' Points and BPS
# #### 3.1. Function To Predict Points

# %%
import numpy as np

def w_avg_predict(player_id, gw_start, record_value, weight, subset_num):
    len_value = len(record_value) + 1
    predicted = np.empty(len_value)
    predicted.fill(np.nan)
    p_id = []
    gw = gw_start[:]
    for i in range(subset_num, len_value):
        div = 0
        for idx in range(subset_num,0,-1):
            div += weight[i-idx]
        #print('div =', div)
        pred = 0                
        for ix in range(subset_num,0,-1):
            t = record_value[i-ix] * (weight[i-ix] / div)
            pred += t
        #print('pred =', pred)
        predicted[i] = pred
        p_id.append(player_id)
        gw.append(gw[-1] + 1)
    return p_id, gw, predicted

# %% [markdown]
# #### 3.2. Create Subset Data Based On Player ID

# %%
subset = 3 # Number of previous gameweeks to predict
act_pts = [] # Actual gameweek's points
act_bps = [] # Actual gameweek's BPS
wfdr = []    # FDR for prediction weigth
uni_id = set(gw_perform_df['player_id']) # Set of unique player ID
gw_start = []
for uid in uni_id:
    pts = list(gw_perform_df['points'].loc[gw_perform_df['player_id'].isin([uid])])
    bps = list(gw_perform_df['bps'].loc[gw_perform_df['player_id'].isin([uid])])
    fdr = list(gw_perform_df['fdr'].loc[gw_perform_df['player_id'].isin([uid])])
    gws = list(gw_perform_df['gameweek'].loc[gw_perform_df['player_id'].isin([uid])])
    act_pts.append(pts)
    act_bps.append(bps)
    wfdr.append(fdr)
    gw_start.append(gws[0:subset])

# %% [markdown]
# #### 3.3. Predict Players' Points In Each Gameweeks

# %%
player_id = []  
gameweek = []
pred_pts = []      # Points prediction results using previous gameweeks' points
pred_bps = []      # BPS prediction results using previous gameweeks' BPS
pred_bps_pts = []  # Points prediction results using bps vs points linear regression equation
for pid, gws, p, b, w in zip(uni_id, gw_start, act_pts, act_bps, wfdr):
    player_id.extend([pid]*subset)
    p_id, gw, pts = w_avg_predict(pid, gws, p, w, subset)
    p_id, gw, bps = w_avg_predict(pid, gws, b, w, subset)
    bps_pts = [0.27 * x - 0.1 for x in bps]
    player_id.extend(p_id)
    gameweek.extend(gw)
    pred_pts.extend(pts)
    pred_bps.extend(bps)
    pred_bps_pts.extend(bps_pts)

# %% [markdown]
# #### 3.4. Summarize Prediction Result In Result Data Frame

# %%
result_dict = {'player_id': player_id,
               'gameweek': gameweek,
               'wmap_pts_predict': pred_pts,
               'wmap_bps_predict': pred_bps,
               'bps_pts_predict': pred_bps_pts}
result_df = pd.DataFrame.from_dict(result_dict, orient='index')
result_df = result_df.transpose()
result_df.head()
# Out:
#   player_id gameweek wmap_pts_predict wmap_bps_predict bps_pts_predict
# 0      FWD2        1              NaN              NaN             NaN
# 1      FWD2        2              NaN              NaN             NaN
# 2      FWD2        3              NaN              NaN             NaN
# 3      FWD2        4             11.7             53.2          14.264
# 4      FWD2        5              9.5             42.4          11.348

# %% [markdown]
# #### 3.5. Join Data Frames For Prediction Evaluation

# %%
# Set index in gw_perform_df to 'player_id', and 'gameweek'
gw_perform_df = gw_perform_df.set_index(['player_id', 'gameweek'])

# %%
final_df = result_df.join(gw_perform_df, on=['player_id','gameweek'])
final_df = final_df.drop(['club','entry_id','fdr'], axis=1)
final_df = final_df.join(players_df, on=['player_id'])
final_df = final_df.join(fdr_df, on=['club','gameweek'])
final_df = final_df.drop(['f_entryid', 'club'], axis=1)

# Rearrange columns
col_order = ['player_id','name','position','club_name','gameweek','fdr','ict_index',
             'bps','points','wmap_bps_predict','wmap_pts_predict', 'bps_pts_predict']
final_df = final_df[col_order].set_index('player_id')
final_df.head()
# Out:
#                   name position       club_name gameweek  fdr  ict_index  \
# player_id
# FWD2       Jamie Vardy      FWD  Leicester City        1    2       11.8
# FWD2       Jamie Vardy      FWD  Leicester City        2    3        3.6
# FWD2       Jamie Vardy      FWD  Leicester City        3    5       17.7
# FWD2       Jamie Vardy      FWD  Leicester City        4    2        1.8
# FWD2       Jamie Vardy      FWD  Leicester City        5    2        0.0
#
#             bps  points wmap_bps_predict wmap_pts_predict bps_pts_predict
# player_id
# FWD2       52.0    13.0              NaN              NaN             NaN
# FWD2        6.0     2.0              NaN              NaN             NaN
# FWD2       82.0    17.0              NaN              NaN             NaN
# FWD2       -2.0     2.0             53.2             11.7          14.264
# FWD2        0.0     0.0             42.4              9.5          11.348

# %% [markdown]
# ### 4. Prediction Model Evaluation
# #### 4.1. Evaluation Metrics Data Frame For Prediction Using Recorded Points

# %%
eval_df1 = result_df[['player_id','gameweek','wmap_pts_predict']].copy()
eval_df1 = eval_df1.join(gw_perform_df, on=['player_id','gameweek'], how='inner')
eval_df1 = eval_df1.drop(['entry_id','club','bps','ict_index','fdr'], axis=1)
eval_df1.head()
# Out:
#   player_id gameweek wmap_pts_predict  points
# 0      FWD2        1              NaN      13
# 1      FWD2        2              NaN       2
# 2      FWD2        3              NaN      17
# 3      FWD2        4             11.7       2
# 4      FWD2        5              9.5       0

# %%
# Evaluation of predicted values using previous average points
eval_df1['pts_error'] = eval_df1.points - eval_df1.wmap_pts_predict
eval_df1['pts_abs_error'] = np.abs(eval_df1.points - eval_df1.wmap_pts_predict)
eval_df1['pts_sq_error'] = np.square(eval_df1.points - eval_df1.wmap_pts_predict)
eval_df1['pts_abs_%_error'] = np.abs(eval_df1.pts_error / eval_df1.points)
eval_df1 = eval_df1.replace([np.inf, -np.inf], np.nan)

eval_df1.head()
# Out:
#   player_id  gameweek  wmap_pts_predict  points  pts_error  pts_abs_error  \
# 0      FWD2         1               NaN      13        NaN            NaN
# 1      FWD2         2               NaN       2        NaN            NaN
# 2      FWD2         3               NaN      17        NaN            NaN
# 3      FWD2         4              11.7       2       -9.7            9.7
# 4      FWD2         5               9.5       0       -9.5            9.5
#
#    pts_sq_error  pts_abs_%_error
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3         94.09             4.85
# 4         90.25              NaN

# %%
cum_pts = eval_df1.groupby(by='player_id').cumsum()
eval_df1[['cum_error','cum_abs_error', 'cum_sq_error', 'cum_abs%_error']] = cum_pts[['pts_error','pts_abs_error','pts_sq_error','pts_abs_%_error']]
eval_df1.head()
# Out:
#   player_id  gameweek  wmap_pts_predict  points  pts_error  pts_abs_error  \
# 0      FWD2         1               NaN      13        NaN            NaN
# 1      FWD2         2               NaN       2        NaN            NaN
# 2      FWD2         3               NaN      17        NaN            NaN
# 3      FWD2         4              11.7       2       -9.7            9.7
# 4      FWD2         5               9.5       0       -9.5            9.5
#
#    pts_sq_error  pts_abs_%_error  cum_error  cum_abs_error  cum_sq_error  \
# 0           NaN              NaN        NaN            NaN           NaN
# 1           NaN              NaN        NaN            NaN           NaN
# 2           NaN              NaN        NaN            NaN           NaN
# 3         94.09             4.85       -9.7            9.7         94.09
# 4         90.25              NaN      -19.2           19.2        184.34
#
#    cum_abs%_error
# 0             NaN
# 1             NaN
# 2             NaN
# 3            4.85
# 4             NaN

# %%
pts_mad = []
pts_mse = []
pts_mape = []
un_id = list(set(eval_df1['player_id'])) # Set of unique player ID
for ui in un_id:
    p_mad = list(eval_df1['cum_abs_error'].loc[eval_df1['player_id'].isin([ui])])
    p_mad = p_mad[subset:]
    mad_run = np.empty(subset)
    mad_run[:]=np.nan
    mad_run = list(mad_run)
    for n,m in enumerate(p_mad):
        mad = m/(n+1)
        mad_run.append(mad)
    pts_mad.extend(mad_run)
    
    p_mse = list(eval_df1['cum_sq_error'].loc[eval_df1['player_id'].isin([ui])])
    p_mse = p_mse[subset:]
    mse_run = np.empty(subset)
    mse_run[:]=np.nan
    mse_run = list(mse_run)
    for n,m in enumerate(p_mse):
        mse = m/(n+1)
        mse_run.append(mse)
    pts_mse.extend(mse_run)
    
    p_mape = list(eval_df1['cum_abs%_error'].loc[eval_df1['player_id'].isin([ui])])
    p_mape = p_mape[subset:]
    mape_run = np.empty(subset)
    mape_run[:]=np.nan
    mape_run = list(mape_run)
    for n,m in enumerate(p_mape):
        mape = m/(n+1)
        mape_run.append(mape)
    pts_mape.extend(mape_run)

eval_df1['pts_mad'] = pts_mad
eval_df1['pts_mse'] = pts_mse
eval_df1['pts_mape'] = pts_mape
eval_df1['pts_ts'] = eval_df1.cum_error / eval_df1.pts_mad
eval_df1.head(30)
# Out:
#    player_id  gameweek  wmap_pts_predict  points  pts_error  pts_abs_error  \
# 0       FWD2         1               NaN      13        NaN            NaN
# 1       FWD2         2               NaN       2        NaN            NaN
# 2       FWD2         3               NaN      17        NaN            NaN
# 3       FWD2         4         11.700000       2  -9.700000       9.700000
# 4       FWD2         5          9.500000       0  -9.500000       9.500000
# 5       FWD2         6          9.888889       7  -2.888889       2.888889
# 6       FWD2         7          4.000000      14  10.000000      10.000000
# 7       FWD2         8          7.000000       4  -3.000000       3.000000
# 8       FWD2         9          7.555556       2  -5.555556       5.555556
# 10     DEF29         1               NaN       0        NaN            NaN
# 11     DEF29         2               NaN       0        NaN            NaN
# 12     DEF29         3               NaN       0        NaN            NaN
# 13     DEF29         4          0.000000       2   2.000000       2.000000
# 14     DEF29         5          1.000000       4   3.000000       3.000000
# 15     DEF29         6          2.000000       0  -2.000000       2.000000
# 16     DEF29         7          1.777778       4   2.222222       2.222222
# 17     DEF29         8          2.285714       6   3.714286       3.714286
# 18     DEF29         9          2.857143       6   3.142857       3.142857
# 20      MID2         2               NaN       3        NaN            NaN
# 21      MID2         3               NaN       8        NaN            NaN
# 22      MID2         4               NaN      24        NaN            NaN
# 23      MID2         5         13.444444       3 -10.444444      10.444444
# 24      MID2         6         12.400000       1 -11.400000      11.400000
# 25      MID2         7         11.000000      15   4.000000       4.000000
# 26      MID2         8          6.555556       6  -0.555556       0.555556
# 27      MID2         9          7.888889       1  -6.888889       6.888889
# 29     MID15         1               NaN       0        NaN            NaN
# 30     MID15         2               NaN       0        NaN            NaN
# 31     MID15         3               NaN       6        NaN            NaN
# 32     MID15         4          2.000000       2   0.000000       0.000000
#
#     pts_sq_error  pts_abs_%_error  cum_error  cum_abs_error  cum_sq_error  \
# 0            NaN              NaN        NaN            NaN           NaN
# 1            NaN              NaN        NaN            NaN           NaN
# 2            NaN              NaN        NaN            NaN           NaN
# 3      94.090000         4.850000  -9.700000       9.700000     94.090000
# 4      90.250000              NaN -19.200000      19.200000    184.340000
# 5       8.345679         0.412698 -22.088889      22.088889    192.685679
# 6     100.000000         0.714286 -12.088889      32.088889    292.685679
# 7       9.000000         0.750000 -15.088889      35.088889    301.685679
# 8      30.864198         2.777778 -20.644444      40.644444    332.549877
# 10           NaN              NaN        NaN            NaN           NaN
# 11           NaN              NaN        NaN            NaN           NaN
# 12           NaN              NaN        NaN            NaN           NaN
# 13      4.000000         1.000000   2.000000       2.000000      4.000000
# 14      9.000000         0.750000   5.000000       5.000000     13.000000
# 15      4.000000              NaN   3.000000       7.000000     17.000000
# 16      4.938272         0.555556   5.222222       9.222222     21.938272
# 17     13.795918         0.619048   8.936508      12.936508     35.734190
# 18      9.877551         0.523810  12.079365      16.079365     45.611741
# 20           NaN              NaN        NaN            NaN           NaN
# 21           NaN              NaN        NaN            NaN           NaN
# 22           NaN              NaN        NaN            NaN           NaN
# 23    109.086420         3.481481 -10.444444      10.444444    109.086420
# 24    129.960000        11.400000 -21.844444      21.844444    239.046420
# 25     16.000000         0.266667 -17.844444      25.844444    255.046420
# 26      0.308642         0.092593 -18.400000      26.400000    255.355062
# 27     47.456790         6.888889 -25.288889      33.288889    302.811852
# 29           NaN              NaN        NaN            NaN           NaN
# 30           NaN              NaN        NaN            NaN           NaN
# 31           NaN              NaN        NaN            NaN           NaN
# 32      0.000000         0.000000   0.000000       0.000000      0.000000
#
#     cum_abs%_error    pts_mad     pts_mse  pts_mape    pts_ts
# 0              NaN        NaN         NaN       NaN       NaN
# 1              NaN        NaN         NaN       NaN       NaN
# 2              NaN        NaN         NaN       NaN       NaN
# 3         4.850000   9.700000   94.090000  4.850000 -1.000000
# 4              NaN   9.600000   92.170000       NaN -2.000000
# 5         5.262698   7.362963   64.228560  1.754233 -3.000000
# 6         5.976984   8.022222   73.171420  1.494246 -1.506925
# 7         6.726984   7.017778   60.337136  1.345397 -2.150095
# 8         9.504762   6.774074   55.424979  1.584127 -3.047567
# 10             NaN        NaN         NaN       NaN       NaN
# 11             NaN        NaN         NaN       NaN       NaN
# 12             NaN        NaN         NaN       NaN       NaN
# 13        1.000000   2.000000    4.000000  1.000000  1.000000
# 14        1.750000   2.500000    6.500000  0.875000  2.000000
# 15             NaN   2.333333    5.666667       NaN  1.285714
# 16        2.305556   2.305556    5.484568  0.576389  2.265060
# 17        2.924603   2.587302    7.146838  0.584921  3.453988
# 18        3.448413   2.679894    7.601957  0.574735  4.507404
# 20             NaN        NaN         NaN       NaN       NaN
# 21             NaN        NaN         NaN       NaN       NaN
# 22             NaN        NaN         NaN       NaN       NaN
# 23        3.481481  10.444444  109.086420  3.481481 -1.000000
# 24       14.881481  10.922222  119.523210  7.440741 -2.000000
# 25       15.148148   8.614815   85.015473  5.049383 -2.071367
# 26       15.240741   6.600000   63.838765  3.810185 -2.787879
# 27       22.129630   6.657778   60.562370  4.425926 -3.798398
# 29             NaN        NaN         NaN       NaN       NaN
# 30             NaN        NaN         NaN       NaN       NaN
# 31             NaN        NaN         NaN       NaN       NaN
# 32        0.000000   0.000000    0.000000  0.000000       NaN

# %% [markdown]
# #### 4.2. Create Evaluation Metrics Data Frame For Prediction Using Recorded Bonus Point System

# %%
eval_df2 = result_df[['player_id','gameweek','bps_pts_predict']].copy()
eval_df2 = eval_df2.join(gw_perform_df, on=['player_id','gameweek'], how='inner')
eval_df2 = eval_df2.drop(['entry_id','club','bps','ict_index','fdr'], axis=1)
eval_df2.head()
# Out:
#   player_id gameweek bps_pts_predict  points
# 0      FWD2        1             NaN      13
# 1      FWD2        2             NaN       2
# 2      FWD2        3             NaN      17
# 3      FWD2        4          14.264       2
# 4      FWD2        5          11.348       0

# %%
# Evaluation of predicted values using previous average bonus point system
eval_df2['bps_error'] = eval_df2.points - eval_df2.bps_pts_predict
eval_df2['bps_abs_error'] = np.abs(eval_df2.points - eval_df2.bps_pts_predict)
eval_df2['bps_sq_error'] = np.square(eval_df2.points - eval_df2.bps_pts_predict)
eval_df2['bps_abs_%_error'] = np.abs(eval_df2.bps_error / eval_df2.points)
eval_df2 = eval_df2.replace([np.inf, -np.inf], np.nan)

eval_df2.head()
# Out:
#   player_id  gameweek  bps_pts_predict  points  bps_error  bps_abs_error  \
# 0      FWD2         1              NaN      13        NaN            NaN
# 1      FWD2         2              NaN       2        NaN            NaN
# 2      FWD2         3              NaN      17        NaN            NaN
# 3      FWD2         4           14.264       2    -12.264         12.264
# 4      FWD2         5           11.348       0    -11.348         11.348
#
#    bps_sq_error  bps_abs_%_error
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3    150.405696            6.132
# 4    128.777104              NaN

# %%
cum_pts = eval_df2.groupby(by='player_id').cumsum()
eval_df2[['cum_error','cum_abs_error', 'cum_sq_error', 'cum_abs%_error']] = cum_pts[['bps_error','bps_abs_error','bps_sq_error','bps_abs_%_error']]
eval_df2.head()
# Out:
#   player_id  gameweek  bps_pts_predict  points  bps_error  bps_abs_error  \
# 0      FWD2         1              NaN      13        NaN            NaN
# 1      FWD2         2              NaN       2        NaN            NaN
# 2      FWD2         3              NaN      17        NaN            NaN
# 3      FWD2         4           14.264       2    -12.264         12.264
# 4      FWD2         5           11.348       0    -11.348         11.348
#
#    bps_sq_error  bps_abs_%_error  cum_error  cum_abs_error  cum_sq_error  \
# 0           NaN              NaN        NaN            NaN           NaN
# 1           NaN              NaN        NaN            NaN           NaN
# 2           NaN              NaN        NaN            NaN           NaN
# 3    150.405696            6.132    -12.264         12.264    150.405696
# 4    128.777104              NaN    -23.612         23.612    279.182800
#
#    cum_abs%_error
# 0             NaN
# 1             NaN
# 2             NaN
# 3           6.132
# 4             NaN

# %%
bps_mad = []
bps_mse = []
bps_mape = []
un_id = list(set(eval_df2['player_id'])) # Set of unique player ID
for ui in un_id:
    p_mad = list(eval_df2['cum_abs_error'].loc[eval_df2['player_id'].isin([ui])])
    p_mad = p_mad[subset:]
    mad_run = np.empty(subset)
    mad_run[:]=np.nan
    mad_run = list(mad_run)
    for n,m in enumerate(p_mad):
        mad = m/(n+1)
        mad_run.append(mad)
    bps_mad.extend(mad_run)
    
    p_mse = list(eval_df2['cum_sq_error'].loc[eval_df2['player_id'].isin([ui])])
    p_mse = p_mse[subset:]
    mse_run = np.empty(subset)
    mse_run[:]=np.nan
    mse_run = list(mse_run)
    for n,m in enumerate(p_mse):
        mse = m/(n+1)
        mse_run.append(mse)
    bps_mse.extend(mse_run)
    
    p_mape = list(eval_df2['cum_abs%_error'].loc[eval_df2['player_id'].isin([ui])])
    p_mape = p_mape[subset:]
    mape_run = np.empty(subset)
    mape_run[:]=np.nan
    mape_run = list(mape_run)
    for n,m in enumerate(p_mape):
        mape = m/(n+1)
        mape_run.append(mape)
    bps_mape.extend(mape_run)

eval_df2['bps_mad'] = bps_mad
eval_df2['bps_mse'] = bps_mse
eval_df2['bps_mape'] = bps_mape
eval_df2['bps_ts'] = eval_df2.cum_error / eval_df2.bps_mad
eval_df2.head(30)
# Out:
#    player_id  gameweek  bps_pts_predict  points  bps_error  bps_abs_error  \
# 0       FWD2         1              NaN      13        NaN            NaN
# 1       FWD2         2              NaN       2        NaN            NaN
# 2       FWD2         3              NaN      17        NaN            NaN
# 3       FWD2         4        14.264000       2 -12.264000      12.264000
# 4       FWD2         5        11.348000       0 -11.348000      11.348000
# 5       FWD2         6        12.080000       7  -5.080000       5.080000
# 6       FWD2         7         3.275000      14  10.725000      10.725000
# 7       FWD2         8         6.785000       4  -2.785000       2.785000
# 8       FWD2         9         7.820000       2  -5.820000       5.820000
# 10     DEF29         1              NaN       0        NaN            NaN
# 11     DEF29         2              NaN       0        NaN            NaN
# 12     DEF29         3              NaN       0        NaN            NaN
# 13     DEF29         4        -0.100000       2   2.100000       2.100000
# 14     DEF29         5         1.655000       4   2.345000       2.345000
# 15     DEF29         6         3.410000       0  -3.410000       3.410000
# 16     DEF29         7         3.020000       4   0.980000       0.980000
# 17     DEF29         8         3.525714       6   2.474286       2.474286
# 18     DEF29         9         3.448571       6   2.551429       2.551429
# 20      MID2         2              NaN       3        NaN            NaN
# 21      MID2         3              NaN       8        NaN            NaN
# 22      MID2         4              NaN      24        NaN            NaN
# 23      MID2         5        13.340000       3 -10.340000      10.340000
# 24      MID2         6        12.806000       1 -11.806000      11.806000
# 25      MID2         7        10.970000      15   4.030000       4.030000
# 26      MID2         8         5.360000       6   0.640000       0.640000
# 27      MID2         9         6.560000       1  -5.560000       5.560000
# 29     MID15         1              NaN       0        NaN            NaN
# 30     MID15         2              NaN       0        NaN            NaN
# 31     MID15         3              NaN       6        NaN            NaN
# 32     MID15         4         1.250000       2   0.750000       0.750000
#
#     bps_sq_error  bps_abs_%_error  cum_error  cum_abs_error  cum_sq_error  \
# 0            NaN              NaN        NaN            NaN           NaN
# 1            NaN              NaN        NaN            NaN           NaN
# 2            NaN              NaN        NaN            NaN           NaN
# 3     150.405696         6.132000 -12.264000      12.264000    150.405696
# 4     128.777104              NaN -23.612000      23.612000    279.182800
# 5      25.806400         0.725714 -28.692000      28.692000    304.989200
# 6     115.025625         0.766071 -17.967000      39.417000    420.014825
# 7       7.756225         0.696250 -20.752000      42.202000    427.771050
# 8      33.872400         2.910000 -26.572000      48.022000    461.643450
# 10           NaN              NaN        NaN            NaN           NaN
# 11           NaN              NaN        NaN            NaN           NaN
# 12           NaN              NaN        NaN            NaN           NaN
# 13      4.410000         1.050000   2.100000       2.100000      4.410000
# 14      5.499025         0.586250   4.445000       4.445000      9.909025
# 15     11.628100              NaN   1.035000       7.855000     21.537125
# 16      0.960400         0.245000   2.015000       8.835000     22.497525
# 17      6.122090         0.412381   4.489286      11.309286     28.619615
# 18      6.509788         0.425238   7.040714      13.860714     35.129403
# 20           NaN              NaN        NaN            NaN           NaN
# 21           NaN              NaN        NaN            NaN           NaN
# 22           NaN              NaN        NaN            NaN           NaN
# 23    106.915600         3.446667 -10.340000      10.340000    106.915600
# 24    139.381636        11.806000 -22.146000      22.146000    246.297236
# 25     16.240900         0.268667 -18.116000      26.176000    262.538136
# 26      0.409600         0.106667 -17.476000      26.816000    262.947736
# 27     30.913600         5.560000 -23.036000      32.376000    293.861336
# 29           NaN              NaN        NaN            NaN           NaN
# 30           NaN              NaN        NaN            NaN           NaN
# 31           NaN              NaN        NaN            NaN           NaN
# 32      0.562500         0.375000   0.750000       0.750000      0.562500
#
#     cum_abs%_error    bps_mad     bps_mse  bps_mape    bps_ts
# 0              NaN        NaN         NaN       NaN       NaN
# 1              NaN        NaN         NaN       NaN       NaN
# 2              NaN        NaN         NaN       NaN       NaN
# 3         6.132000  12.264000  150.405696  6.132000 -1.000000
# 4              NaN  11.806000  139.591400       NaN -2.000000
# 5         6.857714   9.564000  101.663067  2.285905 -3.000000
# 6         7.623786   9.854250  105.003706  1.905946 -1.823274
# 7         8.320036   8.440400   85.554210  1.664007 -2.458651
# 8        11.230036   8.003667   76.940575  1.871673 -3.319978
# 10             NaN        NaN         NaN       NaN       NaN
# 11             NaN        NaN         NaN       NaN       NaN
# 12             NaN        NaN         NaN       NaN       NaN
# 13        1.050000   2.100000    4.410000  1.050000  1.000000
# 14        1.636250   2.222500    4.954512  0.818125  2.000000
# 15             NaN   2.618333    7.179042       NaN  0.395290
# 16        1.881250   2.208750    5.624381  0.470313  0.912281
# 17        2.293631   2.261857    5.723923  0.458726  1.984779
# 18        2.718869   2.310119    5.854900  0.453145  3.047771
# 20             NaN        NaN         NaN       NaN       NaN
# 21             NaN        NaN         NaN       NaN       NaN
# 22             NaN        NaN         NaN       NaN       NaN
# 23        3.446667  10.340000  106.915600  3.446667 -1.000000
# 24       15.252667  11.073000  123.148618  7.626333 -2.000000
# 25       15.521333   8.725333   87.512712  5.173778 -2.076253
# 26       15.628000   6.704000   65.736934  3.907000 -2.606802
# 27       21.188000   6.475200   58.772267  4.237600 -3.557574
# 29             NaN        NaN         NaN       NaN       NaN
# 30             NaN        NaN         NaN       NaN       NaN
# 31             NaN        NaN         NaN       NaN       NaN
# 32        0.375000   0.750000    0.562500  0.375000  1.000000
